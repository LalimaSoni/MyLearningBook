# %% [markdown]
# # Hangman Python Code

# %% [markdown]
# - create a list of words
# - select a random word from given list
# - display number of blanks as per random word
# - ask the user for his guess letter
# - check if guessed_letter in the word
# - if yes then fill respective blank with guess_letter, and ask for another guess
# - if not then decrease one life and ask for another guess.
# - define number of lives
# - if all '_' filled then user will win.
# - if guessed letter correct, then no chnages in lives, but remind user for another guess.
# - if all lives exaust , and word not guessed, then user lost the game

# %%
hangman = [
    '''
   -----|
   |    |
   o    |
  /|\   |
  / \   |
        |
      ----
      ''',
    '''
   -----|
   |    |
   o    |
   |\   |
  / \   |
        |
      ----
      ''',
    '''
   -----|
   |    |
   o    |
   |    |
  / \   |
        |
      ----
      ''',
    '''
   -----|
   |    |
   o    |
   |    |
   \    |
        |
      ----
      ''',
    '''
   -----|
   |    |
   o    |
   |    |
        |
        |
      ----
      ''',
    '''
   -----|
   |    |
   o    |
        |
        |
        |
      ----
      ''',
'''
   -----|
   |    |
        |
        |
        |
        |
      ----
      ''',
    '''
   -----|
        |
        |
        |
        |
        |
      ----
      '''
]

# %%
import random
from IPython.display import clear_output
word_list = ["python","time","APPLE","summer","footBALL"]
target_word = random.choice(word_list).lower()
#print(target_word)

display_word = []
for letters in target_word:
    display_word += '_'
print(display_word)

lives = 7
game_over = False
while game_over == False:
    guess_letter = input("Guess a letter : ")
    #print(guess_letter)
    clear_output()
    
    if guess_letter in display_word:
        print("This letter already guessed, try different letter")
    
    if guess_letter in target_word:
        for position in range(len(target_word)):
            if guess_letter == target_word[position]:
                display_word[position] = guess_letter
        
    else:
        lives -= 1
        print(hangman[lives])
        print(lives, "lives left.")
        if lives ==0:
            game_over = True
            print("You lost !!")
            print("Correct word is : ", target_word)
    
    if '_' not in display_word:
        print("You win !!")
        game_over = True
    
    
    print(display_word)
# Out:
#    -----|
#    |    |
#    o    |
#   /|\   |
#   / \   |
#         |
#       ----
#
# 0 lives left.
# You lost !!
# Correct word is :  time
# ['t', '_', '_', '_']
